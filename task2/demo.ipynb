# %% [markdown]
# # A notebook for examples and edge cases

# %% [markdown]
# Here we can see a simple sentence, where given sentence with a horse and an image of a horse
#
# ![image.png](attachment:image.png)

# %% [markdown]
# An example of more complex sentence with chicken mentioning in the text and the photo of chicken
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A quite simple sentence with butterfly in the sentence and in the photo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# An example of False case, where in the sentence butterfly was mentioned, but in the picture was chicken
#
# ![image.png](attachment:image.png)

# %% [markdown]
# An examples of very complex sentence, generated by ChatGPT. Model still able to recognize dog from the sentence and give truth as a result
#
# ![image.png](attachment:image.png)
